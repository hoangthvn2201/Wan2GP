# %% [markdown]
# # Wan2GP on Google Colab
#
# Sets up [Wan2GP](https://github.com/deepbeepmeep/Wan2GP) in a fresh GPU-backed Colab session.
#
# Run the cells in order to prepare the runtime, install dependencies, and launch the Gradio interface. Click on the link in the output from the last cell to launch the app in your browser.
#
# > **Colab VRAM note:** the free tier usually assigns a 15 GB T4 GPU. Most Wan2GP models exceed that budget; the Wan 2.2 TextImage2Video FastWan model works, producing roughly a 5 second 480p clip in about 8 minutes.

# %% [markdown]
# ## 1. Confirm the accelerator
#
# Choose `Runtime → Change runtime type` and select **GPU** before running anything else.
#
# If this cell raises an error, go back to `Runtime → Change runtime type`, pick **GPU** and save.

# %%
import subprocess

try:
    subprocess.run(['nvidia-smi'], check=True)
except Exception as exc:
    raise RuntimeError(
        'GPU not detected. In Colab, open Runtime → Change runtime type, select GPU (or TPU if GPUs are unavailable), save, then rerun this cell.'
    ) from exc

# %% [markdown]
# ## 2. Configure the workspace path
#
# Choose where Wan2GP should be installed. Update `WAN2GP_ROOT` if you prefer a different location.

# %%
from pathlib import Path

WAN2GP_ROOT = Path('/content/wan2gp').resolve()
print(f'Wan2GP will be installed to: {WAN2GP_ROOT}')
# Out:
# Wan2GP will be installed to: /content/wan2gp

# %% [markdown]
# ## 3. Download or update Wan2GP
#
# Clone the repository if it is not present yet; otherwise pull the latest changes.

# %%
import subprocess

repo_url = 'https://github.com/hoangthvn2201/Wan2GP'
if WAN2GP_ROOT.exists():
    print('Repository already exists. Pulling latest changes...')
    subprocess.run(['git', '-C', str(WAN2GP_ROOT), 'pull'], check=True)
else:
    subprocess.run(['git', 'clone', repo_url, str(WAN2GP_ROOT)], check=True)

# %%
# %cd ..
# Out:
# /content

# %%
# !git checkout pipeline-ltx
# Out:
# Branch 'pipeline-ltx' set up to track remote branch 'pipeline-ltx' from 'origin'.
# Switched to a new branch 'pipeline-ltx'

# %%
# !git pull
# Out:
# Already up to date.

# %% [markdown]
# ## 4. Install system dependencies
#
# Install shared libraries needed for video and audio processing. If you see a warning about skipping an extra repository, it is safe to ignore.

# %%
import os, subprocess

env = os.environ.copy()
env['DEBIAN_FRONTEND'] = 'noninteractive'

subprocess.run(['sudo', 'apt-get', 'update', '-qq'], check=True, env=env)
subprocess.run([
    'sudo', 'apt-get', 'install', '-y', '--no-install-recommends',
    'ffmpeg', 'libglib2.0-0', 'libgl1', 'libportaudio2'
], check=True, env=env)
# Out:
# CompletedProcess(args=['sudo', 'apt-get', 'install', '-y', '--no-install-recommends', 'ffmpeg', 'libglib2.0-0', 'libgl1', 'libportaudio2'], returncode=0)

# %% [markdown]
# ## 5. Install Python dependencies
#
# Install PyTorch, xformers and Wan2GP's Python packages.

# %%
# !pip install vieneu[gpu]

# %%
import os, subprocess, sys

env = os.environ.copy()
env.setdefault('DEBIAN_FRONTEND', 'noninteractive')

subprocess.run([sys.executable, '-m', 'pip', 'install', '--upgrade', 'pip', 'setuptools', 'wheel'], check=True, env=env)
# subprocess.run([sys.executable, '-m', 'pip', 'install', 'torch==2.8.0', 'torchvision', 'torchaudio', '--index-url', 'https://download.pytorch.org/whl/cu128'], check=True, env=env)
subprocess.run([sys.executable, '-m', 'pip', 'install',
    '--force-reinstall', '--no-deps',
    'torch==2.8.0', 'torchvision==0.23.0', 'torchaudio==2.8.0',
    '--index-url', 'https://download.pytorch.org/whl/cu128'], check=True, env=env)

subprocess.run([sys.executable, "-m", "pip", "install", "xformers==0.0.32.post2", "--index-url", "https://download.pytorch.org/whl/cu128"],
               check=True, env=env)
subprocess.run([sys.executable, '-m', 'pip', 'install', '-r', str(WAN2GP_ROOT / 'requirements.txt')], check=True, env=env)
# Out:
# CompletedProcess(args=['/usr/bin/python3', '-m', 'pip', 'install', '-r', '/content/wan2gp/requirements.txt'], returncode=0)

# %% [markdown]
# ## 5b. Force a headless matplotlib backend
#
# Ensure Wan2GP's preprocessing tools use the headless Agg backend so Step 6 launches cleanly in Colab.

# %%
from pathlib import Path

# Replace the TkAgg backend with the headless Agg backend if present.
target = WAN2GP_ROOT / 'preprocessing/matanyone/tools/interact_tools.py'
needle = "matplotlib.use('TkAgg')"
replacement = "matplotlib.use('Agg')"

if not target.exists():
    print(f'Skipping: {target} not found.')
else:
    text = target.read_text()
    if replacement in text:
        print('Agg backend already set; no change needed.')
    elif needle in text:
        target.write_text(text.replace(needle, replacement, 1))
        print('Replaced TkAgg with Agg in interact_tools.py.')
    else:
        print('Backend call not found; no change made.')
# Out:
# Agg backend already set; no change needed.

# %% [markdown]
# ## 6. Launch Wan2GP
#
# Run the Gradio interface. You will find the gradio link in the output. Click on the link to access the UI. Keep the cell running to stay connected; stop it with the square **Stop** button when you are finished.

# %%
import os, subprocess, sys, threading, time

env = os.environ.copy()
env.setdefault('WAN_CACHE_DIR', str(WAN2GP_ROOT / 'models'))
cmd = [
    sys.executable,
    '-u',
    'wgp.py',
    '--listen',
    '--server-port', '7860',
    '--share',
    '--profile', '5',
]
print('Launching Wan2GP…')
process = subprocess.Popen(
    cmd,
    cwd=str(WAN2GP_ROOT),
    env=env,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
)
stop_event = threading.Event()

def keepalive():
    while not stop_event.is_set():
        time.sleep(45)
        if stop_event.is_set():
            break
        print('[keepalive] Notebook cell still running…')

keepalive_thread = threading.Thread(target=keepalive, daemon=True)
keepalive_thread.start()

try:
    for line in iter(process.stdout.readline, ''):
        if not line:
            break
        print(line, end='')
except KeyboardInterrupt:
    print('Stopping Wan2GP…')
    process.terminate()
finally:
    stop_event.set()
    process.wait()
    keepalive_thread.join(timeout=1)
    print(f'Wan2GP stopped (return code: {process.returncode}).')
# Out:
# Launching Wan2GP…
# 2026-06-04 08:50:07.434645: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-06-04 08:50:07.507485: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [GGUF][llama.cpp CUDA] kernels unavailable, using fallback
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# [Quanto][INT8] Injected int8 kernels ACTIVE (backend=triton).
# Loaded plugin: Motion Manager (from wan2gp-motion-designer)
# Loaded plugin: Video Creator (from wan2gp-video-creator)
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://6ee97e46b893f9fa9b.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# Traceback (most recent call last):
#   File "/content/wan2gp/plugins/wan2gp-video-creator/llm_client.py", line 141, in generate_script
#     content = _post_chat(cfg, messages, json_mode=True)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/wan2gp/plugins/wan2gp-video-creator/llm_client.py", line 55, in _post_chat
#     resp.raise_for_status()
#   File "/usr/local/lib/python3.12/dist-packages/requests/models.py", line 1026, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://aiapiv2.pekpik.com/v1/chat/completions
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/wan2gp/plugins/wan2gp-video-creator/plugin.py", line 281, in _gen_script
#     script = llm_client.generate_script(cfg, brief_v, int(n))
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/wan2gp/plugins/wan2gp-video-creator/llm_client.py", line 144, in generate_script
#     content = _post_chat(cfg, messages, json_mode=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/wan2gp/plugins/wan2gp-video-creator/llm_client.py", line 55, in _post_chat
#     resp.raise_for_status()
#   File "/usr/local/lib/python3.12/dist-packages/requests/models.py", line 1026, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://aiapiv2.pekpik.com/v1/chat/completions
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/queueing.py", line 625, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2146, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 1664, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/to_thread.py", line 63, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 2518, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 1002, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/utils.py", line 884, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/content/wan2gp/plugins/wan2gp-video-creator/plugin.py", line 283, in _gen_script
#     raise gr.Error(f"Script generation failed: {e}")
# gradio.exceptions.Error: 'Script generation failed: 429 Client Error: Too Many Requests for url: https://aiapiv2.pekpik.com/v1/chat/completions'
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# Traceback (most recent call last):
#   File "/content/wan2gp/plugins/wan2gp-video-creator/llm_client.py", line 141, in generate_script
#     content = _post_chat(cfg, messages, json_mode=True)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/wan2gp/plugins/wan2gp-video-creator/llm_client.py", line 55, in _post_chat
#     resp.raise_for_status()
#   File "/usr/local/lib/python3.12/dist-packages/requests/models.py", line 1026, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://aiapiv2.pekpik.com/v1/chat/completions
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/wan2gp/plugins/wan2gp-video-creator/plugin.py", line 281, in _gen_script
#     script = llm_client.generate_script(cfg, brief_v, int(n))
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/wan2gp/plugins/wan2gp-video-creator/llm_client.py", line 144, in generate_script
#     content = _post_chat(cfg, messages, json_mode=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/wan2gp/plugins/wan2gp-video-creator/llm_client.py", line 55, in _post_chat
#     resp.raise_for_status()
#   File "/usr/local/lib/python3.12/dist-packages/requests/models.py", line 1026, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://aiapiv2.pekpik.com/v1/chat/completions
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/queueing.py", line 625, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2146, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 1664, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/to_thread.py", line 63, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 2518, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 1002, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/utils.py", line 884, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/content/wan2gp/plugins/wan2gp-video-creator/plugin.py", line 283, in _gen_script
#     raise gr.Error(f"Script generation failed: {e}")
# gradio.exceptions.Error: 'Script generation failed: 429 Client Error: Too Many Requests for url: https://aiapiv2.pekpik.com/v1/chat/completions'
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# WanGP API queued client_ids=['api_1780564001282156771_1']
# WanGP API admitted client_id=api_1780564001282156771_1
# [keepalive] Notebook cell still running…
# Loading Model 'ckpts/flux1-chroma_hd_quanto_bf16_int8.safetensors' ...
# [keepalive] Notebook cell still running…
# Loading Text Encoder 'ckpts/T5_xxl_1.1/T5_xxl_1.1_enc_quanto_bf16_int8.safetensors' ...
# ************ Memory Management for the GPU Poor (mmgp 3.7.6) by DeepBeepMeep ************
# Hooked to model 'transformer' (Flux)
# Async loading plan for model 'transformer' : base size of 55.40 MB will be preloaded with a 216.21 MB async shuttle
# Hooked to model 'vae' (AutoEncoder)
# Hooked to model 'text_encoder' (CLIPTextModel)
# Async loading plan for model 'text_encoder' : base size of 72.49 MB will be preloaded with a 13.52 MB async circular shuttle
# Hooked to model 'text_encoder_2' (T5EncoderModel)
# Async loading plan for model 'text_encoder_2' : 619.20 MB will be preloaded (base size of 251.01 MB + 8.3% of recurrent layers data) with a 184.10 MB async circular shuttle
# [Quanto][INT8] Injected Triton int8 kernels are being used.
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# New video saved to Path: outputs/2026-06-04-09h11m31s_seed824949968_Two dogs at the start of a backyard race a golden retriever and border collie side by side, dirt tr.mp4
# Audio notification fallback: /proc/asound/cards is missing (no ALSA devices); using terminal beep.
# WanGP API delaying gallery completion for client_id=api_1780564001282156771_1 until main queue settles
# WanGP API completed client_id=api_1780564001282156771_1 via gallery path=/content/wan2gp/outputs/2026-06-04-09h11m31s_seed824949968_Two dogs at the start of a backyard race a golden retriever and border collie side by side, dirt tr.mp4
# WanGP API queued client_ids=['api_1780564292462726894_1']
# WanGP API forwarding follow-up load_queue_trigger token=1780564292462761701
# WanGP API admitted client_id=api_1780564292462726894_1
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# New video saved to Path: outputs/2026-06-04-09h14m39s_seed560730165_Two dogs mid-race over a wooden ramp in slow motion, border collie in front leaping gracefully, gold.mp4
# WanGP API delaying gallery completion for client_id=api_1780564292462726894_1 until main queue settles
# WanGP API completed client_id=api_1780564292462726894_1 via gallery path=/content/wan2gp/outputs/2026-06-04-09h14m39s_seed560730165_Two dogs mid-race over a wooden ramp in slow motion, border collie in front leaping gracefully, gold.mp4
# [keepalive] Notebook cell still running…
